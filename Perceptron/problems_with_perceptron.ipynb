# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data=pd.DataFrame()
and_data=pd.DataFrame()
xor_data=pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['output']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['output']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['output']=[0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
sns.scatterplot(
    data=and_data,
    x="input1",
    y="input2",
    hue="output",
    s=200  
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
or_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(
    data=or_data,
    x="input1",
    y="input2",
    hue="output",
    s=200  
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
xor_data
# Out:
#    input1  input2  output
# 0       1       1       0
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(
    data=xor_data,
    x="input1",
    y="input2",
    hue="output",
    s=200  
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(
    data=and_data,
    x="input1",
    y="input2",
    hue="output",
    s=200  
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
x1=np.linspace(-1,1,5)
y1=x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(
    data=or_data,
    x="input1",
    y="input2",
    hue="output",
    s=200  
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
# !pip install mlxtend
from mlxtend.plotting import plot_decision_regions
# Out:
# Requirement already satisfied: mlxtend in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=1.16.2 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=0.24.2 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from mlxtend) (3.10.7)
# Requirement already satisfied: joblib>=0.13.2 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/gaurikutakole/.pyenv/versions/3.12.5/lib/python3.12/site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)

# %%
plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values,clf=clf3,legend=2)
# Out:
# <Axes: >
